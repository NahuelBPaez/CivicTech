# %%
# Celda 1 - Conexión e imports para agentes municipales
from dao.mongo_dao import MongoDAO
from dao.agente_municipal_dao import agenteunicipalDAO
from bson import ObjectId

mongo = MongoDAO()
db = mongo.connect()
agente_dao = AgenteMunicipalDAO(mongo)
print("Conectado a DB:", mongo.db.name)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Celda 1 - Conexión e imports para agentes municipales
#       2 from dao.mongo_dao import MongoDAO
# ----> 3 from dao.agente_municipal_dao import AgenteMunicipalDAO
#       4 from bson import ObjectId
#       5
#       6 mongo = MongoDAO()
#
# ImportError: cannot import name 'AgenteMunicipalDAO' from 'dao.agente_municipal_dao' (/home/dionel/Escritorio/Proyecto/CivicTech/dao/agente_municipal_dao.py)

# %%
# Muestra el contenido del archivo para confirmar que la clase existe y está bien escrita
import pathlib
p = pathlib.Path("dao/agente_municipal_dao.py")
print("Archivo existe:", p.exists())
print("Ruta absoluta:", p.resolve())
print("--- Inicio del archivo ---")
print(p.read_text(encoding="utf-8"))
print("--- Fin del archivo ---")
# Out:
# Archivo existe: True
# Ruta absoluta: /home/dionel/Escritorio/Proyecto/CivicTech/dao/agente_municipal_dao.py
# --- Inicio del archivo ---
# # dao/agente_dao.py
# import datetime
# from bson import ObjectId
# from pymongo.errors import DuplicateKeyError, WriteError
# from pymongo import ASCENDING
#
# class AgenteDAO:
#     """
#     DAO para agentes municipales.
#     Reglas de negocio aplicadas:
#      - dni único global entre agentes
#      - email único global entre agentes (si se provee)
#      - cada agente pertenece a un único municipio (municipio_id debe existir)
#      - campos obligatorios: nombre_apellido, dni, municipio_id, cargo
#     """
#     def __init__(self, mongo_dao):
#         self.mongo = mongo_dao
#         self.collection = self.mongo.db["agente"]
#         try:
#             self._ensure_indexes()
#         except Exception:
#             # No interrumpir si la creación de índices falla (p. ej. por duplicados existentes)
#             pass
#
# ...
